# %%
# Just playing around with the parser that was written by a Kaggler.

import sys
sys.path.insert(0, "../script/") # for importing functions
import parser

# %%
f = open('../data/train', 'rb') #assuming train.gz is located in data/
sp = parser.parse_sessions(f)
sessions = [sp.next() for i in range(100)]

# %%
sessions
# Out:
# [{'Day': 4,
#   'Query': [{'Clicks': [{'SERPID': 0, 'TimePassed': 108, 'URLID': 50628761},
#      {'SERPID': 0, 'TimePassed': 1080, 'URLID': 50628761}],
#     'ListOfTerms': [3080290, 4098689],
#     'QueryID': 10047345,
#     'SERPID': 0,
#     'TimePassed': 0,
#     'URL_DOMAIN': [(50504886, 4217515),
#      (9848058, 1084315),
#      (50534229, 4217515),
#      (50591618, 4217515),
#      (26242582, 2597528),
#      (34623075, 3279130),
#      (68893581, 5149883),
#      (50628761, 4217517),
#      (32262001, 3142702),
#      (35443881, 3339757)]}],
#   'SessionID': 0,
#   'USERID': 0},
#  {'Day': 4,
#   'Query': [{'Clicks': [],
#     'ListOfTerms': [1093007],
#     'QueryID': 2057953,
#     'SERPID': 0,
#     'TimePassed': 0,
#     'URL_DOMAIN': [(12695453, 1284095),
#      (20124473, 2056277),
#      (60660113, 4693531),
#      (43489680, 3815814),
#      (16739421, 1741072),
#      (50183154, 4200904),
#      (57295706, 4528754),
#      (21700324, 2228870),
# ...

# %%
sessions[3]['Query']
# Out:
# [{'Clicks': [],
#   'ListOfTerms': [2365113, 2856206, 2491775],
#   'QueryID': 5239394,
#   'SERPID': 0,
#   'TimePassed': 0,
#   'URL_DOMAIN': [(16457319, 1712204),
#    (35513272, 3344594),
#    (50566741, 4217515),
#    (8699936, 1032002),
#    (19587096, 2024884),
#    (52534052, 4295962),
#    (16398219, 1711944),
#    (14941390, 1549526),
#    (45726575, 3933621),
#    (3870230, 510830)]},
#  {'Clicks': [{'SERPID': 1, 'TimePassed': 162, 'URLID': 35513272}],
#   'ListOfTerms': [2365113, 2856206, 2491775, 4219157, 2383044],
#   'QueryID': 5239405,
#   'SERPID': 1,
#   'TimePassed': 76,
#   'URL_DOMAIN': [(16457319, 1712204),
#    (35513272, 3344594),
#    (19587095, 2024884),
#    (54638321, 4409573),
#    (70294280, 5173294),
#    (29007584, 2844548),
#    (65574293, 4975723),
#    (60082408, 4671429),
#    (36666362, 3411741),
#    (33566096, 3248439)]}]
